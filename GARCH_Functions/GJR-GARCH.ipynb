# %%
# !pip install arch #if using notebook, otherwise install in terminal

from arch import arch_model

# %%
am = arch_model(
    returns * 100, #1d array or pandas series
    mean='Zero',    
    vol='GARCH',
    p=1,
    o=1,   
    q=1,
    dist='t' 
)

res = am.fit()
print(res.summary())
